# %% [markdown]
# <a href="https://colab.research.google.com/github/oceanblue71-byte/wind_vibeCoding/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_13%EA%B0%95_%EC%8B%A4%EC%8A%B5(%ED%95%99%EC%8A%B5%EC%9E%90%EC%9A%A9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 13강 파일 실습

# %% [markdown]
# ##13.2 파일의 사용

# %% [markdown]
# **파일 객체 생성 및 파일 읽기**

# %%
#Jobs.txt 파일 업로드
j_fp = open("Jobs.txt","r")

first6 = j_fp.read(6)
left = j_fp.read()  #앞서 6단어 읽었기에 파일포인터가 그쪽으로 옮겨짐, 그 나머지 출력

j_fp = open("Jobs.txt","r")
first_line = j_fp.readline()
second_line = j_fp.readline()
left_lines = j_fp.readlines()

print(first_line)
print("------")
print(second_line)
print("------")
print(left)
j_fp.close()
# Out:
# Stay Hungry. Stay Foolish.
#
# ------
#
#
# ------
# ungry. Stay Foolish.
#
# Steve Jobs,
# June 14 2005, Standford
#
# I am honored to be with you today at your commencement from one of the finest universities in the world. I never graduated from college. Truth be told, this is the closest I've ever gotten to a college graduation. Today I want to tell you three stories from my life. That's it. No big deal. Just three stories.
#
# The first story is about connecting the dots.
#
# I dropped out of Reed College after the first 6 months, but then stayed around as a drop-in for another 18 months or so before I really quit. So why did I drop out?
#
# ...

# %% [markdown]
# open하고 파일을 닫아주지 않으면 문제 발생

# %% [markdown]
# **파일 쓰기와 추가하기**

# %%
#python.txt 파일 생성
p_fp = open("python.txt", "w")
p_fp.write("KNOU Prime College\n")
p_fp.write("Python programing\n")

p_fp = open("python.txt","a")
p_fp.write("by CS\n")

p_fp.close()

# %% [markdown]
# **명언을 읽고 저자를 작성하는 프로그램**

# %%
#파일 업로드 및 읽기
k_fp = open("Khan.txt", "r", encoding="UTF-8")

# %% [markdown]
# ##13.3 비텍스트 파일의 사용

# %% [markdown]
# **사각형 객체 저장/읽기 프로그램**

# %%
#사각형 클래스
class Rectangle:
